# %%
contacts=({"ammi":7865432167,
           "abbu":9987600564,
           "huzzu":987634578})

# %%
contacts
# Out:
# {'ammi': 7865432167, 'abbu': 9987600564, 'huzzu': 987634578}

# %%
contacts.updates({"huzzu":9900645570})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 contacts.updates({"huzzu":9900645570})
#
# AttributeError: 'dict' object has no attribute 'updates'

# %%
contacts.updates({"sara"987634578})
# Out:
#   Cell In[4], line 1
#     contacts.updates({"sara"987634578})
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
contacts
# Out:
# {'ammi': 7865432167, 'abbu': 9987600564, 'huzzu': 987634578}

# %%
contacts.update({"huzzu":8316789527})

# %%
contacts
# Out:
# {'ammi': 7865432167, 'abbu': 9987600564, 'huzzu': 8316789527}

# %%
contacts.get("nameera")
m="this contact is not found"

# %%
m
# Out:
# 'this contact is not found'

# %%
for names,number in contacts.items():
    print(f"contacts:{names}|phone:{number}")
# Out:
# contacts:ammi|phone:7865432167
# contacts:abbu|phone:9987600564
# contacts:huzzu|phone:8316789527
