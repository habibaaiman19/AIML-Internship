# %%
raw_logs = ["ID01","IDO2","ID03","ID01","ID02","ID05","ID08"]

# %%
unique_users = set (raw_logs)

# %%
is_id05_present = "ID05"in unique_users

# %%
print("Raw login Logs:",raw_logs)
# Out:
# Raw login Logs: ['ID01', 'IDO2', 'ID03', 'ID01', 'ID02', 'ID05', 'ID08']

# %%
print("Unique Users Set:",unique_users)
# Out:
# Unique Users Set: {'ID03', 'ID02', 'ID05', 'ID08', 'IDO2', 'ID01'}

# %%
print("Is'ID05'present?:",is_id05_present)
# Out:
# Is'ID05'present?: True

# %%
print("\ncount comparison:")
# Out:
# count comparison:

# %%
print("Total log entries :",len(raw_logs))
# Out:
# Total log entries : 7

# %%
print("unique users entries:",len(unique_users))
# Out:
# unique users entries: 6

# %%
friend_a = {"python","cooking","hiking","movies"}
friend_b ={"hiking","gameing","photography","python"}

# %%
friend_a&(friend_b)
# Out:
# {'hiking', 'python'}

# %%
friend_a|(friend_b)
# Out:
# {'cooking', 'gameing', 'hiking', 'movies', 'photography', 'python'}

# %%
friend_a-(friend_b)
# Out:
# {'cooking', 'movies'}
