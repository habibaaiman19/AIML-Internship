# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sample={
    "Name":["Aiman","Nameera","Habiba"],
    "Age":[24,22,23],
    "Course":["AI","OS","DSA",]
}
sample
# Out:
# {'Name': ['Aiman', 'Nameera', 'Habiba'],
#  'Age': [24, 22, 23],
#  'Course': ['AI', 'OS', 'DSA']}

# %%
df=pd.DataFrame(sample)
df
# Out:
#       Name  Age Course
# 0    Aiman   24     AI
# 1  Nameera   22     OS
# 2   Habiba   23    DSA

# %%
data=pd.read_csv(r"C:\Users\Aiman\Downloads\data_visualization.csv")

# %%
data
# Out:
#     Unnamed: 0  Student_ID     Name  Gender Department  Age  Math_Score  \
# 0            0           1    Aarav    Male         CS   21          78
# 1            1           2     Diya  Female         IT   22          85
# 2            2           3    Rohan    Male         CS   20          90
# 3            3           4    Sneha  Female        ECE   21          67
# 4            4           5    Arjun    Male         IT   23          88
# 5            5           6    Meera  Female        ECE   22          76
# 6            6           7    Kiran    Male         CS   21          92
# 7            7           8   Ananya  Female         IT   20          81
# 8            8           9    Rahul    Male        ECE   22          74
# 9            9          10     Isha  Female         CS   23          89
# 10          10          11   Vikram    Male         IT   21          84
# 11          11          12    Pooja  Female         CS   20          91
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  Student_ID   Name  Gender Department  Age  Math_Score  \
# 0           0           1  Aarav    Male         CS   21          78
# 1           1           2   Diya  Female         IT   22          85
# 2           2           3  Rohan    Male         CS   20          90
# 3           3           4  Sneha  Female        ECE   21          67
# 4           4           5  Arjun    Male         IT   23          88
#
#    Science_Score  Attendance_Percentage  Study_Hours_per_Week
# 0             75                     85                    10
# 1             88                     90                    12
# 2             85                     95                    15
# 3             70                     80                     8
# 4             90                     92                    14

# %%
plt.figure()
sns.pairplot(data)

# %%
plt.plot(data.Math_Score,color="red")

# %%
plt.plot(data.Math_Score,color="red")
plt.grid()
plt.title("Line plot")
plt.xlabel("Time series")
plt.ylabel("Math marks")
plt.show()

# %%
img = plt.imread(r"C:\Users\Aiman\Downloads\WhatsApp Image 2026-02-11 at 10.47.01 PM(1).jpeg")
plt.imshow(img)
