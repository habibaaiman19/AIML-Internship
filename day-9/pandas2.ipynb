# %%
import pandas as pd
data =pd.read_csv(r"C:\Users\Aiman\Downloads\test2.csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
data.loc["0":"1","Name":"Department"]
# Out:
#     Name   Age Department
# 0  Alice  25.0         HR
# 1    Bob  30.0         IT

# %%
data.loc[1:3,"Name":"Department"]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data.iloc[1:4,1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"})
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
data.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"},inplace=True)

# %%
data
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data
# Out:
#          N     A        D        S
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
data["updated_Salary"]=data["S"]+5000

# %%
data
# Out:
#          N     A        D        S  updated_Salary
# 0    Alice  25.0       HR  50000.0         55000.0
# 1      Bob  30.0       IT  60000.0         65000.0
# 2  Charlie  35.0  Finance  70000.0         75000.0
# 3    David   NaN       IT  62000.0         67000.0
# 4      Eve  29.0       HR      NaN             NaN
# 5    Alice  25.0       HR  50000.0         55000.0

# %%
data["updated_Salary2"]=data["S"].map(lambda x:x+10000)

# %%
data
# Out:
#          N     A        D        S  updated_Salary  updated_Salary2
# 0    Alice  25.0       HR  50000.0         55000.0          60000.0
# 1      Bob  30.0       IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0  Finance  70000.0         75000.0          80000.0
# 3    David   NaN       IT  62000.0         67000.0          72000.0
# 4      Eve  29.0       HR      NaN             NaN              NaN
# 5    Alice  25.0       HR  50000.0         55000.0          60000.0

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#          N     A        D        S  updated_Salary  updated_Salary2
# 0    Alice  25.0       HR  50000.0         55000.0          60000.0
# 1      Bob  30.0       IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0  Finance  70000.0         75000.0          80000.0
# 5    Alice  25.0       HR  50000.0         55000.0          60000.0

# %%
data.head()
# Out:
#          N     A        D        S  updated_Salary  updated_Salary2
# 0    Alice  25.0       HR  50000.0         55000.0          60000.0
# 1      Bob  30.0       IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0  Finance  70000.0         75000.0          80000.0
# 5    Alice  25.0       HR  50000.0         55000.0          60000.0

# %%
data.isnull().sum()
# Out:
# N                  0
# A                  0
# D                  0
# S                  0
# updated_Salary     0
# updated_Salary2    0
# dtype: int64

# %%
data =pd.read_csv(r"C:\Users\Aiman\Downloads\test2.csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data.head()
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           0
# Department    0
# Salary        0
# dtype: int64

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David  28.8         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
data["Age"]=data.Age.astype("int")

# %%
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data["updated_Salary"]=data["Salary"]+5000

# %%
data
# Out:
#       Name  Age Department   Salary  updated_Salary
# 0    Alice   25         HR  50000.0         55000.0
# 1      Bob   30         IT  60000.0         65000.0
# 2  Charlie   35    Finance  70000.0         75000.0
# 5    Alice   25         HR  50000.0         55000.0

# %%
data["updated_Salary2"]=data["Salary"].map(lambda x:x+10000)

# %%
data
# Out:
#       Name  Age Department   Salary  updated_Salary  updated_Salary2
# 0    Alice   25         HR  50000.0         55000.0          60000.0
# 1      Bob   30         IT  60000.0         65000.0          70000.0
# 2  Charlie   35    Finance  70000.0         75000.0          80000.0
# 5    Alice   25         HR  50000.0         55000.0          60000.0

# %%
data[data["Age"]>25]
# Out:
#       Name  Age Department   Salary  updated_Salary  updated_Salary2
# 1      Bob   30         IT  60000.0         65000.0          70000.0
# 2  Charlie   35    Finance  70000.0         75000.0          80000.0

# %%
data["Age"] = data["Age"].fillna(value=data["Age"].mean())

# %%
data
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David  28.8         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
data["Salary"] = data["Salary"].fillna(value=data["Salary"].mean())

# %%
data
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David  28.8         IT  62000.0
# 4      Eve  29.0         HR  58400.0
# 5    Alice  25.0         HR  50000.0

# %%
data["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
data["Age"] = data["Age"].fillna(method="ffill")
data["Salary"] = data["Salary"].fillna(method="bfill")
# Out:
# C:\Users\Aiman\AppData\Local\Temp\ipykernel_8916\700211552.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Age"] = data["Age"].fillna(method="ffill")
# C:\Users\Aiman\AppData\Local\Temp\ipykernel_8916\700211552.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Salary"] = data["Salary"].fillna(method="bfill")

# %%
data
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David  28.8         IT  62000.0
# 4      Eve  29.0         HR  58400.0
# 5    Alice  25.0         HR  50000.0

# %%
data.Age.ffill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
data["updated_salary"] = data["Salary"].apply(lambda x:x+500)

# %%
data
# Out:
#       Name   Age Department   Salary  updated_salary
# 0    Alice  25.0         HR  50000.0         50500.0
# 1      Bob  30.0         IT  60000.0         60500.0
# 2  Charlie  35.0    Finance  70000.0         70500.0
# 3    David  28.8         IT  62000.0         62500.0
# 4      Eve  29.0         HR  58400.0         58900.0
# 5    Alice  25.0         HR  50000.0         50500.0

# %%
data["level"]=data.apply(lambda h:"High" if h["Salary"]>60000 else "Low",axis=1)

# %%
data
# Out:
#       Name   Age Department   Salary  updated_salary level
# 0    Alice  25.0         HR  50000.0         50500.0   Low
# 1      Bob  30.0         IT  60000.0         60500.0   Low
# 2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3    David  28.8         IT  62000.0         62500.0  High
# 4      Eve  29.0         HR  58400.0         58900.0   Low
# 5    Alice  25.0         HR  50000.0         50500.0   Low

# %%
data["level"]=data.apply(lambda h:"High" if h["updated_salary"]>60000 else "Low",axis=1)

# %%
data
# Out:
#       Name   Age Department   Salary  updated_salary level
# 0    Alice  25.0         HR  50000.0         50500.0   Low
# 1      Bob  30.0         IT  60000.0         60500.0  High
# 2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3    David  28.8         IT  62000.0         62500.0  High
# 4      Eve  29.0         HR  58400.0         58900.0   Low
# 5    Alice  25.0         HR  50000.0         50500.0   Low

# %%
data.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         52800.0
# IT         61000.0
# Name: Salary, dtype: float64

# %%
filtered = data[(data["Age"] >28)&(data["Salary"] >50000)]

# %%
filtered
# Out:
#       Name   Age Department   Salary  updated_salary level
# 1      Bob  30.0         IT  60000.0         60500.0  High
# 2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3    David  28.8         IT  62000.0         62500.0  High
# 4      Eve  29.0         HR  58400.0         58900.0   Low

# %%
filtered = data[(data["Age"] >28)&(data["Department"] =="IT")]

# %%
filtered
# Out:
#     Name   Age Department   Salary  updated_salary level
# 1    Bob  30.0         IT  60000.0         60500.0  High
# 3  David  28.8         IT  62000.0         62500.0  High
