# %%
import numpy as np
import pandas as pd

# %%
data=pd.Series([1,2,3,4,5],index=["a","b","c","d","e"])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data.name="numbers"

# %%
data.size
# Out:
# 5

# %%
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data.size
# Out:
# 5

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
data.shape
# Out:
# (5,)

# %%
data["a"]
# Out:
# 1

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.loc["a"::2],data.iloc[3]
# Out:
# (a    1
#  c    3
#  e    5
#  dtype: int64,
#  4)

# %%
data.loc[["a","c","e"]],data.iloc[3]
# Out:
# (a    1
#  c    3
#  e    5
#  dtype: int64,
#  4)

# %%
import pandas as pd
data={
    "usn":[1,2,3,4],
    "name":["aiman","nameera","keeru","neha"],
    "age":[23,21,26,22],
    "branch":["cs","AI","cs","dsa"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    usn     name  age branch
# 0    1    aiman   23     cs
# 1    2  nameera   21     AI
# 2    3    keeru   26     cs
# 3    4     neha   22    dsa
